# %% [markdown]
# # FoDS - Lab Evaluation 1 - 19CSE304
# - Name : Aravind S
# - Roll No : CB.EN.U4CSE20208
# - Set No. : 2 (for even roll)
# - Submission Time : 4:00pm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1

# %%
# to read csv into a dataFrame
df = pd.read_csv('IoTBotNetDataset.csv')
# Out:
# C:\Users\aravi\AppData\Local\Temp\ipykernel_28532\1084233145.py:2: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('IoTBotNetDataset.csv')

# %%
# to write it back or save it the disk
df.to_csv('dataset-save.csv')

# %% [markdown]
# ## Q2

# %%
# drop unnecessary columns
list(df)
# Out:
# ['pkSeqID',
#  'stime',
#  'flags',
#  'flgs_number',
#  'proto',
#  'proto_number',
#  'saddr',
#  'sport',
#  'daddr',
#  'dport',
#  'pkts',
#  'bytes',
#  'state',
#  'state_number',
#  'ltime',
#  'seq',
#  'dur',
#  'mean',
#  'stddev',
#  'sum',
#  'min',
#  'max',
#  'spkts',
#  'dpkts',
#  'sbytes',
#  'dbytes',
#  'rate',
#  'srate',
#  'drate',
#  'TnBPSrcIP',
#  'TnBPDstIP',
#  'TnP_PSrcIP',
#  'TnP_PDstIP',
#  'TnP_PerProto',
#  'TnP_Per_Dport',
#  'AR_P_Proto_P_SrcIP',
#  'AR_P_Proto_P_DstIP',
#  'N_IN_Conn_P_DstIP',
#  'N_IN_Conn_P_SrcIP',
#  'AR_P_Proto_P_Sport',
#  'AR_P_Proto_P_Dport',
#  'Pkts_P_State_P_Protocol_P_DestIP',
#  'Pkts_P_State_P_Protocol_P_SrcIP',
#  'attack',
#  'category',
#  'subcategory']

# %%
# cols being dropped = N_IN_Conn_P_DstIP, N_IN_Conn_P_SrcIP

# %%
col1 = 'N_IN_Conn_P_DstIP'
col2 = 'N_IN_Conn_P_SrcIP'

dfDropped = df.drop([col1, col2], axis=1)
list(dfDropped)
# Out:
# ['pkSeqID',
#  'stime',
#  'flags',
#  'flgs_number',
#  'proto',
#  'proto_number',
#  'saddr',
#  'sport',
#  'daddr',
#  'dport',
#  'pkts',
#  'bytes',
#  'state',
#  'state_number',
#  'ltime',
#  'seq',
#  'dur',
#  'mean',
#  'stddev',
#  'sum',
#  'min',
#  'max',
#  'spkts',
#  'dpkts',
#  'sbytes',
#  'dbytes',
#  'rate',
#  'srate',
#  'drate',
#  'TnBPSrcIP',
#  'TnBPDstIP',
#  'TnP_PSrcIP',
#  'TnP_PDstIP',
#  'TnP_PerProto',
#  'TnP_Per_Dport',
#  'AR_P_Proto_P_SrcIP',
#  'AR_P_Proto_P_DstIP',
#  'AR_P_Proto_P_Sport',
#  'AR_P_Proto_P_Dport',
#  'Pkts_P_State_P_Protocol_P_DestIP',
#  'Pkts_P_State_P_Protocol_P_SrcIP',
#  'attack',
#  'category',
#  'subcategory']

# %% [markdown]
# ## Q3

# %%
# Missing Value Analysis

# %%
# dropping rows having na
naDropped = df.dropna()
naDropped
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport            daddr dport  ...  \
# 0       192.168.100.147  49960    192.168.100.7    80  ...
# ...

# %%
# dropping particular columns having na
colsToDrop = ['AR_P_Proto_P_Sport', 'AR_P_Proto_P_Dport']
colDropped = df.dropna(subset = colsToDrop)
colDropped
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport            daddr dport  ...  \
# 0       192.168.100.147  49960    192.168.100.7    80  ...
# ...

# %%
# we can also use fillna to fill places where there is na

# %% [markdown]
# ## Q4

# %%
# Outlier Analysis using Boxplot
# cols chosen = min and max

m = df.head(100)

# %%
m
# Out:
#     pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0       1.0  1.528089e+09     e          1.0   tcp           1.0
# 1       2.0  1.528089e+09     e          1.0   arp           2.0
# 2       3.0  1.528089e+09     e          1.0   UDP           1.0
# 3       4.0  1.528089e+09     i          1.0   tcp           1.0
# 4       5.0  1.528089e+09     e          1.0   UDP           1.0
# ..      ...           ...   ...          ...   ...           ...
# 95     96.0  1.528089e+09     e          1.0   tcp           1.0
# 96     97.0  1.528089e+09     e          1.0   tcp           1.0
# 97     98.0  1.528089e+09     e          1.0   tcp           1.0
# 98     99.0  1.528089e+09     e          1.0   tcp           1.0
# 99    100.0  1.528089e+09     e          1.0   tcp           1.0
#
#               saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0   192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# ...

# %%
m.boxplot('stime', 'bytes')
# with this we can find the outliers
# Out:
# <AxesSubplot:title={'center':'stime'}, xlabel='bytes'>

# %%
# now we must check for outliers in the given boxplot, 
# and detect and remove them

# %%
# we can also make use of 
# z score
# IQR inorder for outlier analysis

# %% [markdown]
# ## Q5

# %%
# Correlation Analysis
# Variables chosen = min and max
corr = df["min"].corr(df["max"])
print ("Correlation Analysis between min and max : ", round(corr, 2))
# Out:
# Correlation Analysis between min and max :  0.39

# %%
# Inference

# for the taken columns the correlation is positive, i.e they are directly proportional
# the strength is week since correlation is closer to 0 than 1

# %% [markdown]
# ## Q6

# %%
df.describe()
# Out:
#              pkSeqID         stime    flgs_number   proto_number  \
# count  996297.000000  9.962970e+05  996297.000000  996294.000000
# mean   500191.103927  1.528083e+09       1.808430       1.765398
# std    287942.231266  1.754173e+03       1.107501       0.972087
# min         1.000000  1.528081e+09       1.000000       1.000000
# 25%    251331.000000  1.528081e+09       1.000000       1.000000
# 50%    500405.000000  1.528081e+09       2.000000       1.000000
# 75%    749479.000000  1.528085e+09       2.000000       3.000000
# max    998553.000000  1.528089e+09       6.000000       4.000000
#
#                 pkts          bytes   state_number         ltime  \
# count  996297.000000  996297.000000  996297.000000  9.962970e+05
# mean        6.520403     614.684976       2.826334  1.528083e+09
# std         8.634993     605.434762       1.210459  1.752839e+03
# min         1.000000     120.000000       1.000000  1.528081e+09
# ...

# %% [markdown]
# ## Q7

# %%
df.head(3)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0      1.0  1.528089e+09     e          1.0   tcp           1.0
# 1      2.0  1.528089e+09     e          1.0   arp           2.0
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# 1    192.168.100.7     -1  192.168.100.147    -1  ...         15267.20000
# 2  192.168.100.147  49962    192.168.100.7    80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0               96.0              75.0            1.133720
# 1                1.0               2.0            0.005142
# 2               96.0              75.0            1.135100
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 0            1.129970                             770.0
# ...

# %% [markdown]
# ## Q8

# %%
df.tail(4)
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 998549  192.168.100.149  24882  192.168.100.5    80  ...            0.269102
# 998550  192.168.100.149  24883  192.168.100.5    80  ...            0.269102
# 998551  192.168.100.149  24884  192.168.100.5    80  ...            0.269102
# 998552  192.168.100.149  24885  192.168.100.5    80  ...            0.269102
#
#         N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 998549              100.0             100.0            0.269107
# 998550              100.0             100.0            0.269107
# ...

# %% [markdown]
# ## Q9

# %%
df.loc[df['proto'] == 'UDP'].head(1)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 2  192.168.100.147  49962  192.168.100.7    80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 2               96.0              75.0              1.1351
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 2             1.12997                             770.0
#
#    Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 2                            602.0     1.0       DoS         HTTP
#
# [1 rows x 46 columns]

# %% [markdown]
# ## Q10

# %%
# gives rows and cols
df.shape
# Out:
# (998553, 46)

# %%
print("No. of Rows : ", df.shape[0])
# Out:
# No. of Rows :  998553

# %% [markdown]
# ## Q11

# %%
df.iloc[:1,:5]
# Out:
#    pkSeqID         stime flags  flgs_number proto
# 0      1.0  1.528089e+09     e          1.0   tcp

# %% [markdown]
# ## Q12

# %%
# ic = df[df.flags == 'i']
# ic
d = df.groupby('flags').size()
print('Count of packets with flag as i : ', d['i'])
# Out:
# Count of packets with flag as i :  30

# %% [markdown]
# ## Q13

# %%
df.groupby('pkts')

# %%
chk = df.groupby('pkts')['pkts'].count()
chk
# Out:
# pkts
# 1.0            4
# 2.0           19
# 3.0        98393
# 4.0       108721
# 5.0       220590
# 6.0       196210
# 7.0       121929
# 8.0        29219
# 9.0        54127
# 10.0       45837
# 11.0       43071
# 12.0       48849
# 13.0       29280
# 14.0           7
# 15.0          16
# 16.0           5
# 17.0           2
# 18.0           2
# 19.0           1
# 22.0           3
# 23.0           1
# 29.0           3
# 30.0           1
# 35.0           2
# 50.0           1
# 56.0           1
# 67.0           1
# 5724.0         1
# 5886.0         1
# Name: pkts, dtype: int64

# %%
grp1 = df[df.pkts <=10]
grp1
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport            daddr dport  ...  \
# 0       192.168.100.147  49960    192.168.100.7    80  ...
# ...

# %%
grp2 = df[df.pkts > 10]
grp2
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 144        145.0  1.528089e+09   e s          2.0   tcp           1.0
# 276        277.0  1.528089e+09   e s          2.0   tcp           1.0
# 277        278.0  1.528089e+09   e s          2.0   UDP           1.0
# 278        279.0  1.528089e+09   e s          2.0   UDP           1.0
# 283        284.0  1.528089e+09   e s          2.0   tcp           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998213  998214.0  1.528085e+09     e          1.0   udp           3.0
# 998214  998215.0  1.528085e+09     e          1.0   udp           3.0
# 998215  998216.0  1.528085e+09     e          1.0   udp           3.0
# 998216  998217.0  1.528085e+09     e          1.0   udp           3.0
# 998217  998218.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# ...

# %% [markdown]
# ## Q13

# %%
#q13-a
givenStime = 1528088522
temp1 = df[df.stime == givenStime]
temp1
# Out:
#      pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0        1.0  1.528089e+09     e          1.0   tcp           1.0
# 1        2.0  1.528089e+09     e          1.0   arp           2.0
# 2        3.0  1.528089e+09     e          1.0   UDP           1.0
# 3        4.0  1.528089e+09     i          1.0   tcp           1.0
# 4        5.0  1.528089e+09     e          1.0   UDP           1.0
# ..       ...           ...   ...          ...   ...           ...
# 302    303.0  1.528089e+09     e          1.0   tcp           1.0
# 303    304.0  1.528089e+09     e          1.0   tcp           1.0
# 304    305.0  1.528089e+09     e          1.0   tcp           1.0
# 305    306.0  1.528089e+09     e          1.0   tcp           1.0
# 306    307.0  1.528089e+09     e          1.0   tcp           1.0
#
#                saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0    192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# ...

# %%
print('Average pkts for stime(', givenStime, ') :', temp1['pkts'].mean())
# Out:
# Average pkts for stime( 1528088522 ) : 8.069204152249135

# %%
#q13-b
print('Average sbytes for stime(', givenStime, ') :', temp1['sbytes'].mean())
# Out:
# Average sbytes for stime( 1528088522 ) : 792.7923875432526

# %%
#q3-c
print('Average dbytes for stime(', givenStime, ') :', temp1['dbytes'].mean())
# Out:
# Average dbytes for stime( 1528088522 ) : 1001.9480968858131

# %% [markdown]
# ## Q14

# %%
# groupby mean and variance for HTTP and TCP

http = df[df.subcategory == 'HTTP']
tcp = df[df.subcategory == 'TCP']

# %%
http
# Out:
#       pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0         1.0  1.528089e+09     e          1.0   tcp           1.0
# 1         2.0  1.528089e+09     e          1.0   arp           2.0
# 2         3.0  1.528089e+09     e          1.0   UDP           1.0
# 3         4.0  1.528089e+09     i          1.0   tcp           1.0
# 4         5.0  1.528089e+09     e          1.0   UDP           1.0
# ...       ...           ...   ...          ...   ...           ...
# 1480   1481.0  1.528089e+09     e          1.0   tcp           1.0
# 1481   1482.0  1.528089e+09     e          1.0   tcp           1.0
# 1482   1483.0  1.528089e+09     e          1.0   tcp           1.0
# 1483   1484.0  1.528089e+09     e          1.0   tcp           1.0
# 1484   1485.0  1.528089e+09     e          1.0   tcp           1.0
#
#                 saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0     192.168.100.147  49960    192.168.100.7    80  ...            1.127040
# ...

# %%
tcp
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 1485      1486.0  1.528081e+09   e s          2.0   tcp           1.0
# 1486      1487.0  1.528081e+09   e s          2.0   tcp           1.0
# 1487      1488.0  1.528081e+09   e s          2.0   tcp           1.0
# 1488      1489.0  1.528081e+09   e s          2.0   tcp           1.0
# 1489      1490.0  1.528081e+09   e s          2.0   tcp           1.0
# ...          ...           ...   ...          ...   ...           ...
# 617280  617281.0  1.528081e+09   e g          5.0   tcp           1.0
# 617281  617282.0  1.528081e+09   e s          2.0   tcp           1.0
# 617282  617283.0  1.528081e+09   e s          2.0   tcp           1.0
# 617283  617284.0  1.528081e+09   e s          2.0   tcp           1.0
# 617284  617285.0  1.528081e+09   e s          2.0   tcp           1.0
#
#                   saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# ...

# %%
print('Mean for Pkts_PState_P_Protocol_P_DestIP in case of HTTP : ', http['Pkts_P_State_P_Protocol_P_DestIP'].mean())
#Pkts_P_State_P_Protocol_P_DestIP
# Out:
# Mean for Pkts_PState_P_Protocol_P_DestIP in case of HTTP :  746.0976430976431

# %%
print('Varinace for Pkts_PState_P_Protocol_P_DestIP in case of TCP : ', tcp['Pkts_P_State_P_Protocol_P_DestIP'].var())
# Out:
# Varinace for Pkts_PState_P_Protocol_P_DestIP in case of TCP :  21456.481203405478

# %% [markdown]
# ## Q15

# %%
givenStime1 = 1528088521
givenStime2 = 1528088522
givenStime3 = 1528088523

s1 = df[df.stime == givenStime1]
s2 = df[df.stime == givenStime2]
s3 = df[df.stime == givenStime3]

# %%
s1
# Out:
# Empty DataFrame
# Columns: [pkSeqID, stime, flags, flgs_number, proto, proto_number, saddr, sport, daddr, dport, pkts, bytes, state, state_number, ltime, seq, dur, mean, stddev, sum, min, max, spkts, dpkts, sbytes, dbytes, rate, srate, drate, TnBPSrcIP, TnBPDstIP, TnP_PSrcIP, TnP_PDstIP, TnP_PerProto, TnP_Per_Dport, AR_P_Proto_P_SrcIP, AR_P_Proto_P_DstIP, N_IN_Conn_P_DstIP, N_IN_Conn_P_SrcIP, AR_P_Proto_P_Sport, AR_P_Proto_P_Dport, Pkts_P_State_P_Protocol_P_DestIP, Pkts_P_State_P_Protocol_P_SrcIP, attack, category, subcategory]
# Index: []
#
# [0 rows x 46 columns]

# %%
s2
# Out:
#      pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0        1.0  1.528089e+09     e          1.0   tcp           1.0
# 1        2.0  1.528089e+09     e          1.0   arp           2.0
# 2        3.0  1.528089e+09     e          1.0   UDP           1.0
# 3        4.0  1.528089e+09     i          1.0   tcp           1.0
# 4        5.0  1.528089e+09     e          1.0   UDP           1.0
# ..       ...           ...   ...          ...   ...           ...
# 302    303.0  1.528089e+09     e          1.0   tcp           1.0
# 303    304.0  1.528089e+09     e          1.0   tcp           1.0
# 304    305.0  1.528089e+09     e          1.0   tcp           1.0
# 305    306.0  1.528089e+09     e          1.0   tcp           1.0
# 306    307.0  1.528089e+09     e          1.0   tcp           1.0
#
#                saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0    192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# ...

# %%
s3
# Out:
#      pkSeqID         stime flags  flgs_number proto  proto_number  \
# 279    280.0  1.528089e+09   e s          2.0   tcp           1.0
# 280    281.0  1.528089e+09   e s          2.0   tcp           1.0
#
#                saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 279  192.168.100.148  51966  192.168.100.7    80  ...             1.87472
# 280  192.168.100.149  52818  192.168.100.3    80  ...             1.24099
#
#      N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 279                8.0               8.0             1.56277
# 280               90.0              76.0             1.51642
#
#      AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 279             1.27818                              71.0
# 280             1.27818                             754.0
#
#      Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 279                             71.0     1.0       DoS         HTTP
# ...

# %%
# using 'pkts since the question asks for packets
s1['pkts'].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
s2['pkts'].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
s3['pkts'].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
# END
